# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import sys
folder = '/content/gdrive/My Drive/Colab Notebooks/eva5/session 13/YoloV3'
sys.path.append(folder)

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.6.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
ls
# Out:
# gdrive/  sample_data/

# %%
cd /content/gdrive/My Drive/Colab Notebooks/eva5/session 13/YoloV3
# Out:
# /content/gdrive/My Drive/Colab Notebooks/eva5/session 13/YoloV3

# %%
# !ls
# Out:
#  annotation_tool   output	  runs		   utils
#  cfg		   __pycache__	  test.py	   vim.exe.stackdump
#  data		   README.md	  ting		   weights
#  detect.py	   results.json   train.py
#  models.py	   results.png	 'ubdivisions=1'

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=3, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', device='', epochs=3, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-10-24 09:06:28.490993: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (20 found, 0 missing, 0 empty, 0 duplicate, for 20 images): 100% 20/20 [00:00<00:00, 1048.72it/s]
# Caching images (0.0GB): 100% 20/20 [00:00<00:00, 96.22it/s]
# ...

# %%
# !python train.py --data data/YoloV3_Dataset/YoloV3_Dataset.data --batch 16 --cache --epochs 25 --nosave
# Out:
# Namespace(accumulate=4, adam=False, batch_size=16, bucket='', cache_images=True, cfg='cfg/yolov3-spp.cfg', data='data/YoloV3_Dataset/YoloV3_Dataset.data', device='', epochs=25, evolve=False, img_size=[512], multi_scale=False, name='', nosave=True, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-10-25 09:20:28.191420: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# Caching labels (3110 found, 145 missing, 45 empty, 0 duplicate, for 3300 images): 100% 3300/3300 [00:02<00:00, 1122.10it/s]
# Caching images (1.8GB): 100% 3300/3300 [00:28<00:00, 117.28it/s]
# ...

# %%
# !python detect.py --conf-thres 0.1 --source data/YoloV3_Dataset/video --output out_out1
# Out:
# Namespace(agnostic_nms=False, augment=False, cfg='cfg/yolov3-custom.cfg', classes=None, conf_thres=0.1, device='', fourcc='mp4v', half=False, img_size=512, iou_thres=0.6, names='data/YoloV3_Dataset/YoloV3_Dataset.names', output='out_out1', save_txt=False, source='data/YoloV3_Dataset/video', view_img=False, weights='weights/last.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# Model Summary: 225 layers, 6.25895e+07 parameters, 6.25895e+07 gradients
# image 1/367 data/YoloV3_Dataset/video/frame0.jpg: 320x512 1 hardhats, Done. (0.031s)
# image 2/367 data/YoloV3_Dataset/video/frame1.jpg: 320x512 1 hardhats, Done. (0.030s)
# image 3/367 data/YoloV3_Dataset/video/frame10.jpg: 320x512 1 hardhats, Done. (0.030s)
# image 4/367 data/YoloV3_Dataset/video/frame100.jpg: 320x512 1 hardhats, Done. (0.030s)
# image 5/367 data/YoloV3_Dataset/video/frame101.jpg: 320x512 1 hardhats, Done. (0.030s)
# ...

# %%
Image(filename='out_out1/frame1.jpg', width=600)

# %%
Image(filename='out_out1/frame102.jpg', width=600)

# %%
Image(filename='out_out/img003.jpg', width=600)

# %%
Image(filename='out_out/img020.jpg', width=600)

# %%
Image(filename='out_out/img010.jpg', width=600)
